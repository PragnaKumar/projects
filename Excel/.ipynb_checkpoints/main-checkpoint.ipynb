# %%
import pandas as pd
df = pd.read_excel('July_month_attendance.xlsx')

# %%
df.columns
# Out:
# Index(['Code', 'Name', 'Date', 'First In Time', 'Exit-1', 'Punch In-1',
#        'DurationOut-1', 'Exit-2', 'Punch In-2', 'DurationOut-2', 'Exit-3',
#        'Punch In-3', 'DurationOut-3', 'Exit-4', 'Punch In-4', 'DurationOut-4',
#        'Exit-5', 'Punch In-5', 'DurationOut-5', 'Exit-6', 'Punch In-6',
#        'DurationOut-6', 'Exit-7', 'Punch In-7', 'DurationOut-7', 'Exit-8',
#        'Punch In-8', 'DurationOut-8', 'Exit-9', 'Punch In-9', 'DurationOut-9',
#        'Exit-10', 'Punch In-10', 'DurationOut-10', 'Exit-11', 'Punch In-11',
#        'DurationOut-11', 'Exit-12', 'Punch In-12', 'DurationOut-12', 'Exit-13',
#        'Punch In-13', 'DurationOut13', 'Exit-14', 'Punch In-14',
#        'DurationOut-14', 'Exit-15', 'Punch In-15', 'DurationOut-15', 'Exit-16',
#        'Punch In-16', 'DurationOut-16', 'Exit-17', 'Punch In-17',
#        'DurationOut-17', 'Exit-18', 'Punch In-18', 'DurationOut-18', 'Exit-19',
#        'Punch In-19', 'DurationOut-19', 'Exit-20', 'Punch In-20',
#        'DurationOut-20', 'Exit-21', 'Punch In-21', 'DurationOut-21', 'Exit-22',
#        'Punch In-22', 'DurationOut-22', 'Exit-23', 'Punch In-23',
#        'DurationOut-23', 'Exit-24', 'Punch In-24', 'DurationOut-24', 'Exit-25',
#        'Punch In-25', 'DurationOut-25', 'Exit-26', 'Punch In-26',
#        'DurationOut-26', 'Exit-27', 'Punch In-27', 'DurationOut-27', 'Exit-28',
#        'Punch In-28', 'DurationOut-28', 'Exit-29', 'Punch In-29',
#        'DurationOut29', 'Exit-30', 'Punch In-30', 'DurationOut30',
#        'Last Out Time', 'Total Punch In', 'Total Punch Out', 'Total Out Time',
#        'Total In Time', 'Total Duration'],
#       dtype='object')

# %%
duration_df = df[['Code', 'Name', 'Date', 'First In Time','Last Out Time', 'Total Out Time', 'Total In Time', 'Total Duration'] +\
                  df.columns[df.columns.str.startswith("DurationOut")].tolist()]
print(duration_df.columns)
grouped_df = duration_df.groupby(df['Code'])
# Out:
# Index(['Code', 'Name', 'Date', 'First In Time', 'Last Out Time',
#        'Total Out Time', 'Total In Time', 'Total Duration', 'DurationOut-1',
#        'DurationOut-2', 'DurationOut-3', 'DurationOut-4', 'DurationOut-5',
#        'DurationOut-6', 'DurationOut-7', 'DurationOut-8', 'DurationOut-9',
#        'DurationOut-10', 'DurationOut-11', 'DurationOut-12', 'DurationOut13',
#        'DurationOut-14', 'DurationOut-15', 'DurationOut-16', 'DurationOut-17',
#        'DurationOut-18', 'DurationOut-19', 'DurationOut-20', 'DurationOut-21',
#        'DurationOut-22', 'DurationOut-23', 'DurationOut-24', 'DurationOut-25',
#        'DurationOut-26', 'DurationOut-27', 'DurationOut-28', 'DurationOut29',
#        'DurationOut30'],
#       dtype='object')

# %%
pd.to_timedelta(duration_df.iloc[0]+":00").dt.total_seconds().sum() / 3600
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     170 try:
# --> 171     result = func(left, right)
#     172 except TypeError:
#
# TypeError: unsupported operand type(s) for +: 'datetime.time' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pd.to_timedelta(duration_df.iloc[0]+":00").dt.total_seconds().sum() / 3600
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)
#     184     moose     3.0     NaN
#     185     """
# --> 186     return self._arith_method(other, operator.add)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:6112, in Series._arith_method(self, other, op)
#    6110 def _arith_method(self, other, op):
#    6111     self, other = ops.align_method_SERIES(self, other)
# -> 6112     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\base.py:1348, in IndexOpsMixin._arith_method(self, other, op)
#    1345 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1347 with np.errstate(all="ignore"):
# -> 1348     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1350 return self._construct_result(result, name=res_name)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:232, in arithmetic_op(left, right, op)
#     228     _bool_arith_check(op, left, right)
#     230     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     231     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 232     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     234 return res_values
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:178, in _na_arithmetic_op(left, right, op, is_cmp)
#     172 except TypeError:
#     173     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     174         # For object dtype, fallback to a masked operation (only operating
#     175         #  on the non-missing values)
#     176         # Don't do this for comparisons, as that will handle complex numbers
#     177         #  incorrectly, see GH#32047
# --> 178         result = _masked_arith_op(left, right, op)
#     179     else:
#     180         raise
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:135, in _masked_arith_op(x, y, op)
#     132         mask = np.where(y == 1, False, mask)
#     134     if mask.any():
# --> 135         result[mask] = op(xrav[mask], y)
#     137 np.putmask(result, ~mask, np.nan)
#     138 result = result.reshape(x.shape)  # 2D compat
#
# TypeError: unsupported operand type(s) for +: 'datetime.time' and 'str'

# %%
duration_df
# Out:
#         Code          Name        Date First In Time Last Out Time  \
# 0      U0001  Krishnan K M  01/07/2023      10:05:00      20:19:00
# 1      U0001  Krishnan K M  02/07/2023      00:00:00      00:00:00
# 2      U0001  Krishnan K M  03/07/2023      10:00:00      18:36:00
# 3      U0001  Krishnan K M  04/07/2023      09:42:00      21:18:00
# 4      U0001  Krishnan K M  05/07/2023      09:16:00      19:56:00
# ...      ...           ...         ...           ...           ...
# 16910  UT335   Madhura K L  18/07/2023      08:48:00      18:49:00
# 16911  UT335   Madhura K L  19/07/2023      08:57:00      18:55:00
# 16912  UT335   Madhura K L  20/07/2023      08:51:00      18:39:00
# 16913  UT335   Madhura K L  21/07/2023      08:48:00      18:39:00
# 16914  UT335   Madhura K L  21/07/2023      08:48:00      00:00:00
#
#       Total Out Time Total In Time Total Duration DurationOut-1 DurationOut-2  \
# 0           07:50:00      02:24:00          10:14         07:50           NaN
# 1           00:00:00      00:00:00              0           NaN           NaN
# 2           02:00:00      06:36:00          08:36         00:27         01:33
# 3           05:05:00      06:31:00          11:36         05:04         00:01
# 4           04:55:00      05:45:00          10:40         00:01         00:00
# ...              ...           ...            ...           ...           ...
# 16910       00:35:00      09:26:00          10:01         00:34         00:01
# 16911       00:21:00      09:37:00          09:58         00:21           NaN
# 16912       00:00:00      09:48:00          09:48           NaN           NaN
# 16913       00:26:00      09:25:00          09:51         00:26           NaN
# 16914       00:00:00      00:00:00              0           NaN           NaN
#
#        ... DurationOut-21 DurationOut-22 DurationOut-23 DurationOut-24  \
# 0      ...            NaN            NaN            NaN            NaN
# 1      ...            NaN            NaN            NaN            NaN
# 2      ...            NaN            NaN            NaN            NaN
# 3      ...            NaN            NaN            NaN            NaN
# 4      ...            NaN            NaN            NaN            NaN
# ...    ...            ...            ...            ...            ...
# 16910  ...            NaN            NaN            NaN            NaN
# 16911  ...            NaN            NaN            NaN            NaN
# 16912  ...            NaN            NaN            NaN            NaN
# 16913  ...            NaN            NaN            NaN            NaN
# 16914  ...            NaN            NaN            NaN            NaN
#
#       DurationOut-25 DurationOut-26 DurationOut-27 DurationOut-28  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 16910            NaN            NaN            NaN            NaN
# 16911            NaN            NaN            NaN            NaN
# 16912            NaN            NaN            NaN            NaN
# 16913            NaN            NaN            NaN            NaN
# 16914            NaN            NaN            NaN            NaN
#
#       DurationOut29 DurationOut30
# 0               NaN           NaN
# 1               NaN           NaN
# 2               NaN           NaN
# 3               NaN           NaN
# 4               NaN           NaN
# ...             ...           ...
# 16910           NaN           NaN
# 16911           NaN           NaN
# 16912           NaN           NaN
# 16913           NaN           NaN
# 16914           NaN           NaN
#
# [16915 rows x 38 columns]

# %%
df2 = duration_df.fillna("00:00")
unique_code = df2['Code'].unique()
for code in unique_code:
    df_filtered = df2[df2["Code"]==code]
    #df[filter] = pd.to_timedelta(df[filter] + ':00')
    #df_timedeltas = duration_df.apply(lambda col: pd.to_timedelta(col))
    column_filter = df_filtered[df_filtered.columns[df_filtered.columns.str.startswith('DurationOut')]]
    for x in range(len(df_filtered)):
        df_filtered.iloc[x]
        total_duration = pd.to_timedelta(column_filter.iloc[x]+":00").dt.total_seconds().sum() / 3600
        total_intime = pd.to_timedelta(df['Total Duration'].astype(str)).diff(-1).dt.total_seconds().div(60)
        data = {'Total_DurationOut': [total_duration],
               'Total_In_Time' : [total_intime]}
        df = pd.DataFrame(data)
        # Format the 'Total_Duration_Hours' column
        df['Total_DurationOut'] = df['Total_DurationOut'].apply(lambda x: '{:02}:{:02}:{:02}'.format(int(x), int((x * 60) % 60), int((x * 3600) % 60)))
        print(df)
    break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx:440, in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx:472, in pandas._libs.tslibs.timedeltas._item_to_timedelta64_fastpath()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx:638, in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: expected hh:mm:ss format
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 11
#       9 df_filtered.iloc[x]
#      10 total_duration = pd.to_timedelta(column_filter.iloc[x]+":00").dt.total_seconds().sum() / 3600
# ---> 11 total_intime = pd.to_timedelta(df['Total Duration'].astype(str)).diff(-1).dt.total_seconds().div(60)
#      12 data = {'Total_DurationOut': [total_duration],
#      13        'Total_In_Time' : [total_intime]}
#      14 df = pd.DataFrame(data)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\timedeltas.py:189, in to_timedelta(arg, unit, errors)
#     187     return arg
#     188 elif isinstance(arg, ABCSeries):
# --> 189     values = _convert_listlike(arg._values, unit=unit, errors=errors)
#     190     return arg._constructor(values, index=arg.index, name=arg.name)
#     191 elif isinstance(arg, ABCIndex):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\timedeltas.py:248, in _convert_listlike(arg, unit, errors, name)
#     245     arg = np.array(arg, dtype=object)
#     247 try:
# --> 248     td64arr = sequence_to_td64ns(arg, unit=unit, errors=errors, copy=False)[0]
#     249 except ValueError:
#     250     if errors == "ignore":
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\timedeltas.py:912, in sequence_to_td64ns(data, copy, unit, errors)
#     909 # Convert whatever we have into timedelta64[ns] dtype
#     910 if is_object_dtype(data.dtype) or is_string_dtype(data.dtype):
#     911     # no need to make a copy, need to convert if string-dtyped
# --> 912     data = _objects_to_td64ns(data, unit=unit, errors=errors)
#     913     copy = False
#     915 elif is_integer_dtype(data.dtype):
#     916     # treat as multiples of the given unit
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\timedeltas.py:1041, in _objects_to_td64ns(data, unit, errors)
#    1038 # coerce Index to np.ndarray, converting string-dtype if necessary
#    1039 values = np.array(data, dtype=np.object_, copy=False)
# -> 1041 result = array_to_timedelta64(values, unit=unit, errors=errors)
#    1042 return result.view("timedelta64[ns]")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx:454, in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx:493, in pandas._libs.tslibs.timedeltas._item_to_timedelta64()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx:484, in pandas._libs.tslibs.timedeltas._item_to_timedelta64()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx:363, in pandas._libs.tslibs.timedeltas.convert_to_timedelta64()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx:638, in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: expected hh:mm:ss format

# %%
df_filtered = duration_df.fillna("00:00")
unique_code = df_filtered['Code'].unique()
# for code in unique_code:
#     df_filtered = df2[df2["Code"]==code]
    #df[filter] = pd.to_timedelta(df[filter] + ':00')
    #df_timedeltas = duration_df.apply(lambda col: pd.to_timedelta(col))
column_filter = df_filtered[df_filtered.columns[df_filtered.columns.str.startswith('DurationOut')]]
column_filter2 = df_filtered['Total Duration']
for x in range(len(df_filtered)):
    #df_filtered.iloc[x]
    total_outduration = pd.to_timedelta(column_filter.iloc[x] + ":00").dt.total_seconds().sum() / 3600
    total_duration = pd.to_timedelta(column_filter2.iloc[x] + ":00").total_seconds()

    time_difference = pd.to_timedelta(total_duration, unit='s') - pd.to_timedelta(total_outduration, unit='s')

    #print(f'Time difference: {time_difference}')
    hours, remainder = divmod(time_difference_seconds.seconds, 3600)
    minutes = remainder // 60

    time_difference_str = f'{int(hours):02}:{int(minutes):02}'

    #print(total_duration)
    #print(total_outduration)
    #print(time_difference)
    data = {'Total_DurationOut': [total_outduration],
           'Total_In_Duration': [time_difference_str]}
    new_data = pd.DataFrame(data)
    # Format the 'Total_Duration_Hours' column
    new_data['Total_DurationOut'] = new_data['Total_DurationOut'].apply(lambda x: '{:02}:{:02}:{:02}'.format(int(x), int((x * 60) % 60), int((x * 3600) % 60)))
    new_data['Total_In_Duration'] = new_data['Total_In_Duration']
    
    print(new_data)
    #print(column_filter)Total_In_Duration
    #result_df.to_excel('output14.xlsx', index=False)
    break
# Out:
#   Total_DurationOut Total_In_Duration
# 0          07:50:00             02:24

# %%
df_filtered = duration_df.fillna("00:00")
unique_code = df2['Code'].unique()
column_filter = df_filtered[df_filtered.columns[df_filtered.columns.str.startswith('DurationOut')]]
column_filter2 = df_filtered['Total Duration']

total_outduration = []
time_difference_list = []  
#duration_percent = []
for x in range(len(df_filtered)):
    total_outduration.append(pd.to_timedelta(column_filter.iloc[x]+":00").dt.total_seconds().sum() / 3600)
    total_duration = pd.to_timedelta(column_filter2.iloc[x]+":00").total_seconds()

    time_difference = pd.to_timedelta(total_duration, unit='s') - pd.to_timedelta(total_outduration, unit='s')
    time_difference_list.append(time_difference)  
    
df_filtered["Total_Out_Duration"] = total_outduration
df_filtered["Total_Out_Duration"] = df_filtered["Total_Out_Duration"].apply(lambda x: '{:02}:{:02}:{:02}'.format(int(x), int((x * 60) % 60), int((x * 3600) % 60)))

df_filtered['Total_In_Duration'] = time_difference_list
df_filtered["Total_In_Duration"].apply(lambda x: '{:02}:{:02}:{:02}'.format(int(x), int((x * 60) % 60), int((x * 3600) % 60)))

#df_filtered["Out_Percentage"] = duration_percent

selected_columns = ['Code', 'Name', 'Date', 'First In Time', 'Last Out Time', 'Total_In_Duration', 'Total_Out_Duration']

result_pd = df_filtered[selected_columns]

#df_filtered.to_excel("result.xlsx")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 11
#       9 for x in range(len(df_filtered)):
#      10     total_outduration.append(pd.to_timedelta(column_filter.iloc[x]+":00").dt.total_seconds().sum() / 3600)
# ---> 11     total_duration = pd.to_timedelta(column_filter2.iloc[x]+":00").total_seconds()
#      13     time_difference = pd.to_timedelta(total_duration, unit='s') - pd.to_timedelta(total_outduration, unit='s')
#      14     time_difference_list.append(time_difference)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
result_pd.head()

# %%
df_filtered = duration_df.fillna("00:00")
unique_code = df2['Code'].unique()
column_filter = df_filtered[df_filtered.columns[df_filtered.columns.str.startswith('DurationOut')]]
column_filter2 = df_filtered['Total Duration']

total_outduration = []
#duration_percent = []
for x in range(len(df_filtered)):
    total_outduration.append(pd.to_timedelta(column_filter.iloc[x]+":00").dt.total_seconds().sum() / 3600)
    total_duration = pd.to_timedelta(column_filter2.iloc[x]+":00").total_seconds()
    
    time_difference = pd.to_timedelta(total_duration) - pd.to_timedelta(total_outduration)
    #duration_percent = [(x / total_duration_sum) * 100 for x in total_duration]
    
    
df_filtered["Total_Out_Duration"] = total_outduration
df_filtered["Total_Out_Duration"] = df_filtered["Total_Out_Duration"].apply(lambda x: '{:02}:{:02}:{:02}'.format(int(x), int((x * 60) % 60), int((x * 3600) % 60)))

df_filtered["Total_In_Duration"] = time_difference

#df_filtered["Out_Percentage"] = duration_percent

selected_columns = ['Code', 'Name', 'Date', 'First In Time', 'Last Out Time',  'Total Duration', 'Total_In_Duration', 'Total_Out_Duration']

result_pd = df_filtered[selected_columns]

#df_filtered.to_excel("result.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 10
#       8 for x in range(len(df_filtered)):
#       9     total_outduration.append(pd.to_timedelta(column_filter.iloc[x]+":00").dt.total_seconds().sum() / 3600)
# ---> 10     total_duration = pd.to_timedelta(column_filter2.iloc[x]).total_seconds()
#      12     time_difference = pd.to_timedelta(total_duration) - pd.to_timedelta(total_outduration)
#      13     #duration_percent = [(x / total_duration_sum) * 100 for x in total_duration]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\timedeltas.py:211, in to_timedelta(arg, unit, errors)
#     208     raise ValueError("unit must not be specified if the input is/contains a str")
#     210 # ...so it must be a scalar value. Return scalar.
# --> 211 return _coerce_scalar_to_timedelta_type(arg, unit=unit, errors=errors)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\timedeltas.py:221, in _coerce_scalar_to_timedelta_type(r, unit, errors)
#     218 result: Timedelta | NaTType
#     220 try:
# --> 221     result = Timedelta(r, unit)
#     222 except ValueError:
#     223     if errors == "raise":
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx:1766, in pandas._libs.tslibs.timedeltas.Timedelta.__new__()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx:638, in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: expected hh:mm:ss format

# %%
re
