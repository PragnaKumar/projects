# %%
# !pip install ultralytics

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.111 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.0/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !unzip "/content/drive/MyDrive/assignments/pneumonia-yolo.zip" -d "/content/drive/MyDrive/assignments/pneumonia-yolo"
# Out:
# Archive:  /content/drive/MyDrive/assignments/pneumonia-yolo.zip
#    creating: /content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/
#   inflating: /content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/data.yaml
#    creating: /content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/test/
#    creating: /content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/test/images/
#   inflating: /content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/test/images/NORMAL2-IM-1155-0001.jpeg
#   inflating: /content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/test/images/NORMAL2-IM-1156-0001.jpeg
#   inflating: /content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/test/images/NORMAL2-IM-1157-0001.jpeg
#   inflating: /content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/test/images/NORMAL2-IM-1158-0001.jpeg
# ...

# %%
# %cd '/content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo'

# !yolo task=segment mode=train model=yolo11n-seg.pt data=data.yaml epochs=100 imgsz=224 plots=True
# Out:
# /content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo
# ...
# 100% 5.90M/5.90M [00:00<00:00, 91.6MB/s]
# Ultralytics 8.3.111 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=segment mode=val model=/content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/runs/segment/train/weights/best.pt data=/content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/data.yaml
# Out:
# Ultralytics 8.3.111 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11n-seg summary (fused): 113 layers, 2,834,958 parameters, 0 gradients, 10.2 GFLOPs
# val: Fast image access ✅ (ping: 1.5±2.2 ms, read: 53.9±40.2 MB/s, size: 218.7 KB)
# val: Scanning /content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/train/labels.cache... 1806 images, 11 backgrounds, 0 corrupt: 100% 1817/1817 [00:00<?, ?it/s]
# train: WARNING ⚠️ /content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/train/images/person906_bacteria_2831.jpeg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 114/114 [02:17<00:00,  1.21s/it]
#                    all       1817       2234       0.98      0.779      0.825      0.819      0.979      0.778      0.823      0.799
# ...

# %% [markdown]
# ## Inference

# %%
# !yolo task=segment mode=predict model=/content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/runs/segment/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/test/images
# Out:
# Ultralytics 8.3.111 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11n-seg summary (fused): 113 layers, 2,834,958 parameters, 0 gradients, 10.2 GFLOPs
#
# image 1/545 /content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/test/images/NORMAL2-IM-1155-0001.jpeg: 192x224 1 normal, 57.8ms
# image 2/545 /content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/test/images/NORMAL2-IM-1156-0001.jpeg: 192x224 1 normal, 42.3ms
# image 3/545 /content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/test/images/NORMAL2-IM-1157-0001.jpeg: 192x224 1 normal, 39.1ms
# image 4/545 /content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/test/images/NORMAL2-IM-1158-0001.jpeg: 224x224 1 normal, 63.8ms
# image 5/545 /content/drive/MyDrive/assignments/pneumonia-yolo/pneumonia-yolo/test/images/NORMAL2-IM-1160-0001.jpeg: 224x224 1 normal, 42.4ms
# ...

# %%
import shutil
import os

# Create zip
shutil.make_archive('runs', 'zip', 'runs')

# Download zip
from google.colab import files
files.download('runs.zip')
